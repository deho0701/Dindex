# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
re = pd.read_csv('./test-result/4-result.csv')
name = '4-result'
re
# Out:
#                             read : 0.5    insert : 0.3    remove : 0.2   \
# 0          message: test make img fiile             NaN             NaN
# 1                        thread num:  4             NaN             NaN
# 2    [micro] Throughput(op/s): 22608658             NaN             NaN
# 3                        thread num:  8             NaN             NaN
# 4    [micro] Throughput(op/s): 40987788             NaN             NaN
# 5                       thread num:  12             NaN             NaN
# 6    [micro] Throughput(op/s): 50143545             NaN             NaN
# 7                       thread num:  16             NaN             NaN
# 8    [micro] Throughput(op/s): 58764784             NaN             NaN
# 9                       thread num:  20             NaN             NaN
# 10   [micro] Throughput(op/s): 86348104             NaN             NaN
# 11                      thread num:  24             NaN             NaN
# 12   [micro] Throughput(op/s): 77277614             NaN             NaN
# 13                      thread num:  28             NaN             NaN
# 14   [micro] Throughput(op/s): 97178616             NaN             NaN
# 15                      thread num:  32             NaN             NaN
# 16   [micro] Throughput(op/s): 96767104             NaN             NaN
# 17                      thread num:  36             NaN             NaN
# 18   [micro] Throughput(op/s): 97063828             NaN             NaN
# 19                      thread num:  40             NaN             NaN
# 20   [micro] Throughput(op/s): 96204647             NaN             NaN
# 21                      thread num:  44             NaN             NaN
# 22  [micro] Throughput(op/s): 101998642             NaN             NaN
# 23                      thread num:  48             NaN             NaN
# 24   [micro] Throughput(op/s): 97818309             NaN             NaN
# 25                      thread num:  52             NaN             NaN
# 26  [micro] Throughput(op/s): 122604436             NaN             NaN
# 27                      thread num:  56             NaN             NaN
# 28              [micro] Worker54 Ready.             NaN             NaN
# 29                      thread num:  60             NaN             NaN
# 30   [micro] Throughput(op/s): 99310035             NaN             NaN
# 31                      thread num:  64             NaN             NaN
# 32  [micro] Throughput(op/s): 117909166             NaN             NaN
# 33                      thread num:  68             NaN             NaN
# 34  [micro] Throughput(op/s): 108465080             NaN             NaN
# 35                      thread num:  72             NaN             NaN
# 36  [micro] Throughput(op/s): 107772715             NaN             NaN
# 37                      thread num:  76             NaN             NaN
# 38  [micro] Throughput(op/s): 116497956             NaN             NaN
# 39                      thread num:  80             NaN             NaN
# 40  [micro] Throughput(op/s): 103653646             NaN             NaN
# 41                      thread num:  84             NaN             NaN
# 42  [micro] Throughput(op/s): 114579649             NaN             NaN
# 43                      thread num:  88             NaN             NaN
# 44  [micro] Throughput(op/s): 143528822             NaN             NaN
# 45                      thread num:  92             NaN             NaN
# 46  [micro] Throughput(op/s): 121241127             NaN             NaN
# 47                      thread num:  96             NaN             NaN
# 48  [micro] Throughput(op/s): 128385697             NaN             NaN
# 49                     thread num:  100             NaN             NaN
# 50  [micro] Throughput(op/s): 130807257             NaN             NaN
#
#      table size : 100
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49                NaN
# 50                NaN

# %%
np =pd.DataFrame(index=range(0,26))
np ['thread num'],np['Throughput'] =0,0

# %%
for i in re.index[1:]: 
    data = re.iloc[i,0].split(':')
    if i%2 == 1:
        np.iloc[i//2,0] = int(data[1])
    else:
        np.iloc[i//2 -1 ,1] = int(data[1])
print(np)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-779cc43bd9de> in <module>
#       4         np.iloc[i//2,0] = int(data[1])
#       5     else:
# ----> 6         np.iloc[i//2 -1 ,1] = int(data[1])
#       7 print(np)
#
# IndexError: list index out of range

# %%
plt.plot(np['thread num'][:24],np['Throughput'][:24],'bo-')
plt.title(name)
plt.xlabel('thread num')
plt.ylabel('Throughput')
plt.annotate(re.columns[0], xy=(297,100),xycoords='figure pixels')
plt.annotate(re.columns[1], xy=(288,90),xycoords='figure pixels')
plt.annotate(re.columns[2], xy=(280,80),xycoords='figure pixels')
plt.annotate(re.columns[3], xy=(270,70),xycoords='figure pixels')
plt.savefig(name+'.png')
